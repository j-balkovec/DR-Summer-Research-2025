# %%
# == sys path ==
from pathlib import Path
import sys

project_root = Path().resolve().parent
sys.path.append(str(project_root))
# == sys path ==
import pandas as pd
import cv2

from utils.visual_check import visual_check

DF_PATH = r'/Users/jbalkovec/Desktop/DR/data/patches/master_df.pkl'

# %%
df = pd.read_pickle(DF_PATH)

# %%
df.head()
# Out:
#   image_id          patch_id                                file_path  \
# 0   0000_1  0000_1_1216_1216  patches/0000_1/all/0000_1_1216_1216.png
# 1   0000_1    0000_1_832_320    patches/0000_1/all/0000_1_832_320.png
# 2   0000_1    0000_1_960_320    patches/0000_1/all/0000_1_960_320.png
# 3   0000_1   0000_1_1088_320   patches/0000_1/all/0000_1_1088_320.png
# 4   0000_1   0000_1_1216_320   patches/0000_1/all/0000_1_1216_320.png
#
#   filter_tag                                        coordinates  \
# 0      black  {'top-left': (1152, 1152), 'top-right': (1279,...
# 1    healthy  {'top-left': (768, 256), 'top-right': (895, 25...
# 2    healthy  {'top-left': (896, 256), 'top-right': (1023, 2...
# 3    healthy  {'top-left': (1024, 256), 'top-right': (1151, ...
# 4    healthy  {'top-left': (1152, 256), 'top-right': (1279, ...
#
#                    center  label_vector
# 0  {'x': 1216, 'y': 1216}  [0, 0, 0, 0]
# 1    {'x': 832, 'y': 320}  [0, 0, 0, 0]
# 2    {'x': 960, 'y': 320}  [0, 0, 0, 0]
# 3   {'x': 1088, 'y': 320}  [0, 0, 0, 0]
# 4   {'x': 1216, 'y': 320}  [0, 0, 0, 0]

# %%
df.tail()
# Out:
#        image_id         patch_id                               file_path  \
# 184195   1841_3  1841_3_1216_320  patches/1841_3/all/1841_3_1216_320.png
# 184196   1841_3  1841_3_1088_320  patches/1841_3/all/1841_3_1088_320.png
# 184197   1841_3   1841_3_960_320   patches/1841_3/all/1841_3_960_320.png
# 184198   1841_3   1841_3_960_448   patches/1841_3/all/1841_3_960_448.png
# 184199   1841_3   1841_3_448_064   patches/1841_3/all/1841_3_448_064.png
#
#        filter_tag                                        coordinates  \
# 184195    healthy  {'top-left': (1152, 256), 'top-right': (1279, ...
# 184196    healthy  {'top-left': (1024, 256), 'top-right': (1151, ...
# 184197    healthy  {'top-left': (896, 256), 'top-right': (1023, 2...
# 184198    healthy  {'top-left': (896, 384), 'top-right': (1023, 3...
# 184199    healthy  {'top-left': (384, 0), 'top-right': (511, 0), ...
#
#                        center  label_vector
# 184195  {'x': 1216, 'y': 320}  [0, 0, 0, 0]
# 184196  {'x': 1088, 'y': 320}  [0, 0, 0, 0]
# 184197   {'x': 960, 'y': 320}  [0, 0, 0, 0]
# 184198   {'x': 960, 'y': 448}  [0, 0, 0, 0]
# 184199    {'x': 448, 'y': 64}  [0, 0, 0, 0]
