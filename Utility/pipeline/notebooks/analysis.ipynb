# %%
# == sys path ==
from pathlib import Path
import sys

project_root = Path().resolve().parent
sys.path.append(str(project_root))
# == sys path ==
import pandas as pd
import cv2

from utils.visual_check import visual_check

DF_PATH = r'/Users/jbalkovec/Desktop/DR/data/patches/master_df.pkl'

# %%
df = pd.read_pickle(DF_PATH)

# %%
df.head()
# Out:
#   image_id          patch_id                                file_path  \
# 0   0000_1  0000_1_0265_0752  patches/0000_1/all/0000_1_0265_0752.png
# 1   0000_1  0000_1_0935_1115  patches/0000_1/all/0000_1_0935_1115.png
# 2   0000_1  0000_1_0729_0375  patches/0000_1/all/0000_1_0729_0375.png
# 3   0000_1  0000_1_0167_0988  patches/0000_1/all/0000_1_0167_0988.png
# 4   0000_1  0000_1_1000_0621  patches/0000_1/all/0000_1_1000_0621.png
#
#   filter_tag                                        coordinates  \
# 0    healthy  {'top-left': (265, 752), 'top-right': (392, 75...
# 1    healthy  {'top-left': (935, 1115), 'top-right': (1062, ...
# 2    healthy  {'top-left': (729, 375), 'top-right': (856, 37...
# 3    healthy  {'top-left': (167, 988), 'top-right': (294, 98...
# 4    healthy  {'top-left': (1000, 621), 'top-right': (1127, ...
#
#                   center  label_vector
# 0   {'x': 265, 'y': 752}  [0, 0, 0, 0]
# 1  {'x': 935, 'y': 1115}  [0, 0, 0, 0]
# 2   {'x': 729, 'y': 375}  [0, 0, 0, 0]
# 3   {'x': 167, 'y': 988}  [0, 0, 0, 0]
# 4  {'x': 1000, 'y': 621}  [0, 0, 0, 0]

# %%
df.tail()
# Out:
#        image_id          patch_id                                file_path  \
# 249155   1841_3  1841_3_0347_0974  patches/1841_3/all/1841_3_0347_0974.png
# 249156   1841_3  1841_3_0634_0272  patches/1841_3/all/1841_3_0634_0272.png
# 249157   1841_3  1841_3_0327_0169  patches/1841_3/all/1841_3_0327_0169.png
# 249158   1841_3  1841_3_0538_0645  patches/1841_3/all/1841_3_0538_0645.png
# 249159   1841_3  1841_3_1266_0917  patches/1841_3/all/1841_3_1266_0917.png
#
#        filter_tag                                        coordinates  \
# 249155     lesion  {'top-left': (347, 974), 'top-right': (474, 97...
# 249156    healthy  {'top-left': (634, 272), 'top-right': (761, 27...
# 249157    healthy  {'top-left': (327, 169), 'top-right': (454, 16...
# 249158    healthy  {'top-left': (538, 645), 'top-right': (665, 64...
# 249159    healthy  {'top-left': (1266, 917), 'top-right': (1393, ...
#
#                        center  label_vector
# 249155   {'x': 347, 'y': 974}  [1, 1, 0, 0]
# 249156   {'x': 634, 'y': 272}  [0, 0, 0, 0]
# 249157   {'x': 327, 'y': 169}  [0, 0, 0, 0]
# 249158   {'x': 538, 'y': 645}  [0, 0, 0, 0]
# 249159  {'x': 1266, 'y': 917}  [0, 0, 0, 0]
