# %%
import cv2
import matplotlib.pyplot as plt


PATCH_PATH = r'/Users/jbalkovec/Desktop/DR/data/patches/1841_3/all/1841_3_192_448.png'

# %%
# load image
PATCH = cv2.imread(PATCH_PATH)

plt.imshow(PATCH)
plt.title('Original Image 128x128')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
# Resize the image to 64x64
PATCH = cv2.resize(PATCH, (64, 64))
plt.imshow(PATCH)

plt.title('Original Image 64x64')
# Out:
# Text(0.5, 1.0, 'Original Image 64x64')
